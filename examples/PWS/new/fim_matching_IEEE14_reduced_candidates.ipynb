# %%
from pathlib import Path
import sys
import pickle

import numpy as np
import cvxpy as cp
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("default")

# %%
sys.path.append(
    "/data/yonatan/myproject/scripts/indicator_config/indicator_configuration/modules",
)
from convex_optimization_mod import ConvexOptMod as ConvexOpt
from utils import tol, eps

# %%
case = 14  # 14-bus case

WORK_DIR = Path().absolute()
DATA_DIR = WORK_DIR / "data" / f"IEEE{case}"
FIM_DIR = DATA_DIR / "FIMs"
RESULT_DIR = WORK_DIR / "results" / f"IEEE{case}"
if not RESULT_DIR.exists():
    RESULT_DIR.mkdir(parents=True)

# %%
# Model information
nparams = 2 * case

# %% [markdown]
# # Remove optimal buses from the original problem

# %% [markdown]
# ## Setup

# %%
# Configurations
configs_all = list(np.arange(case) + 1)
configs_remove = [2, 6, 9]
configs = list(set(configs_all) - set(configs_remove))
nconfigs = len(configs)
config_ids = np.array([f"bus{ii}" for ii in configs])
config_ids
# Out:
# array(['bus1', 'bus3', 'bus4', 'bus5', 'bus7', 'bus8', 'bus10', 'bus11',
#        'bus12', 'bus13', 'bus14'], dtype='<U5')

# %%
# Load configuration FIMs
fim_configs_tensor = np.empty((nconfigs, nparams, nparams))
for ii, bus in enumerate(configs):
    J = np.load(FIM_DIR / f"jacobian_bus{bus}.npy")
    I = J.T @ J
    fim_configs_tensor[ii] = I

# %% [markdown]
# ## Convex optimization

# %%
# Convex optimization
# Settings
cvx_tol = eps ** 0.75
lambda_tol = 1e-5
tol_mat = np.diag(np.ones(nparams)) * lambda_tol
print("Tolerance:", cvx_tol)
print("Lower bound:", lambda_tol)

solver = dict(verbose=True, solver=cp.SDPA, epsilonStar=cvx_tol)

# plt.figure()
wopt = np.ones(nconfigs)
colors = ["r", "g", "b", "k"]
for ii in range(4):
    cvxopt = ConvexOpt(fim_configs_tensor, np.array(config_ids), tol_mat, wopt + 1e-15)

    try:
        # Solve
        cvxopt.solve(solver=solver)
    except Exception:
        break

    wopt = cvxopt.result["wm"]
    dual = cvxopt.result["dual_wm"]
    print("Violation:", cvxopt.constraints[1].violation())
    # print("Weights:", wm)

#     plt.plot(wopt, c=colors[ii], label=ii)
#     plt.plot(dual, c=colors[ii], ls="--")

# plt.yscale("log")
# plt.xticks(range(nconfigs), config_ids, rotation=90)
# plt.ylabel("Weights")
# plt.legend(title="Iteration", bbox_to_anchor=(1, 1))
# plt.show()
# Out:
# Tolerance: 1.8189894035458565e-12
# Lower bound: 1e-05
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:56 PM: Your problem has 11 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:56 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:56 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:56 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:56 PM: Finished problem compilation (took 5.118e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
# SDPA start at [Sun May 19 14:35:56 2024]
# NumThreads  is set as 64
# Schur computation : DENSE
# Converted to SDPA internal data / Starting SDPA main loop
#    mu      thetaP  thetaD  objP      objD      alphaP  alphaD  beta
#  0 1.0e+04 1.0e+00 1.0e+00 -0.00e+00 +2.80e-02 7.0e-01 7.3e-01 2.00e-01
#  1 3.6e+03 3.0e-01 2.7e-01 +1.08e+03 +2.46e-02 9.0e-01 5.2e-01 2.00e-01
#  2 1.7e+03 3.0e-02 1.3e-01 +1.84e+03 +2.12e-02 9.1e-01 7.8e-01 2.00e-01
#  3 4.9e+02 2.6e-03 2.9e-02 +2.24e+03 +1.39e-02 1.0e+00 7.8e-01 2.00e-01
#  4 1.6e+02 2.3e-15 6.2e-03 +2.22e+03 +9.35e-03 1.9e+00 8.4e-01 2.00e-01
#  5 2.9e+01 2.3e-15 1.0e-03 +2.32e+02 +1.83e-03 1.9e+00 8.9e-01 2.00e-01
#  6 4.6e+00 9.1e-15 1.1e-04 +3.81e+01 +1.94e-04 1.6e+00 8.9e-01 2.00e-01
#  7 9.1e-01 9.1e-15 1.1e-05 +1.89e+01 +2.52e-05 1.2e+00 9.0e-01 2.00e-01
#  8 2.4e-01 9.1e-15 1.1e-06 +1.17e+01 +9.19e-06 1.1e+00 1.0e+00 2.00e-01
#  9 4.0e-02 6.8e-15 1.8e-20 +2.47e+00 +6.85e-06 9.6e-01 9.6e-01 1.00e-01
# 10 5.4e-03 8.8e-15 2.5e-20 +3.27e-01 +6.80e-06 9.9e-01 9.9e-01 1.00e-01
# 11 6.0e-04 9.0e-15 6.0e-20 +3.64e-02 +6.75e-06 1.0e+00 8.0e+01 1.00e-01
# 12 6.2e-05 9.0e-15 8.9e-18 +3.80e-03 +7.57e-06 9.6e-01 2.1e+01 1.00e-01
# 13 8.5e-06 9.0e-15 1.8e-16 +5.36e-04 +1.86e-05 7.3e-01 5.3e+00 1Start: getCLPresult.00e-01
# 14 1.8e-06 9.0e-15 7.7e-16 +2.05e-04 +9.33e-05 9.3e-01 9.6e-01 1.00e-01
# 15 2.8e-07 9.0e-15 2.9e-17 +1.47e-04 +1.30e-04 8.7e-01 9.2e-01 1.00e-01
# 16 5.3e-08 9.0e-15 1.6e-18 +1.41e-04 +1.38e-04 8.3e-01 8.5e-01 1.00e-01
# Strange behavior : primal < dual :: line 158 in sdpa_solve.cpp
# 17 1.3e-08 9.0e-15 1.2e-17 +1.40e-04 +1.39e-04 9.0e-01 9.0e-01 1.00e-01
#
# Retrieving result from LMI standard form...
# Making result infomation...
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pdFEAS
#      iteration = 17
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +1.4027172761758006e-04
#        dualObj = +1.3948001406570632e-04
#     dualityGap = +7.9171355187374255e-07
#    primalError = +0.0000000000000000e+00
#      dualError = +1.0089706847793423e-11
#    convertTime = 0.008360
#      solveTime = 0.126021
# retrievingTime = 0.004724
#      totalTime = 0.144149
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:56 PM: Optimal value: 1.401e-04
# (CVXPY) May 19 02:35:56 PM: Compilation took 5.118e-02 seconds
# (CVXPY) May 19 02:35:56 PM: Solver (including time spent in interface) took 1.872e-01 seconds
# Violation: -0.0
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:56 PM: Your problem has 11 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:56 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:56 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:56 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:56 PM: Finished problem compilation (took 5.217e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
# /home/byu.local/yonatank/.local/lib/python3.7/site-packages/cvxpy/problems/problem.py:1388: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   "Solution may be inaccurate. Try another solver, "
# phase.value  = pdFEAS
#    Iteration = 17
#           mu = +1.2978914628387435e-08
# relative gap = +7.9171355187374255e-07
#         gap  = +7.9171355187374255e-07
#      digits  = +2.2471747244991040e+00
# objValPrimal = +1.4027172761758006e-04
# objValDual   = +1.3948001406570632e-04
# p.feas.error = +8.9998841712457534e-13
# d.feas.error = +9.8910421953563032e-12
# total time   = 0.120386
#   main loop time = 0.120382
#       total time = 0.120386
# file  check time = 0.000000
# file change time = 0.000004
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35
# 23 6.0e-11 1.8e-17 4.0e-11 +8.71e+00 +8.71e+00 1.3e+00 1.6e-01 2.00e-01
# 24 4.5e-11 1.8e-17 5.0e-11 +8.71e+00 +8.71e+00 5.5e-02 5.5e-02 2.00e-01
# 25 4.3e-11 8.9e-18 4.7e-11 +8.71e+00 +8.71e+00 1.5e-04 1.5e-04 2.00e-01
# cannot cholesky decomposition :: line 486 in sdpa_linear.cpp
# Could you try with smaller gammaStar? :: line 487 in sdpa_linear.cpp
# 26 4.3e-11 8.9e-18 4.7e-11 +8.71e+00 +8.71e+00 1.1e-01 1.1e-01 2.00e-01
# 27 3.9e-11 1.8e-17 3.8e-11 +8.71e+00 +8.71e+00 2.9e-03 2.9e-03 2.00e-01
# cannot cholesky decomposition :: line 486 in sdpa_linear.cpp
# Could you try with smaller gammaStar? :: line 487 in sdpa_linear.cpp
# cannot cholesky decomposition :: line 486 in sdpa_linear.cpp
# Could you try with smaller gammaStar? :: line 487 in sdpa_linear.cpp
# cannot cholesky decomposition :: line 486 in sdpa_linear.cpp
# Could you try with smaller gammaStar? :: line 487 in sdpa_linear.cpp
# 28 3.9e-11 8.9e-18 3.8e-11 +8.71e+00 +8.71e+00 2.3e-02 2.3e-02 2.00e-01
# 29 3.8e-11 8.9e-18 7.4e-11 +8.71e+00 +8.71e+00 5.0e-01 5.0e-01 2.00e-01
# 30 2.3e-11 8.9e-18 3.4e-11 +8.71e+00 +8.71e+00 7.2e+00 1.7e-02 2.78e-01
# 31 2.0e-11 8.9e-18 3.1e-11 +8.71e+00 +8.71e+00 3.5e-05 3.5e-05 4.28e+00
# Step length is too small.  :: line 198 in sdpa_dataset.cpp
# cannot move: step length is too short :: line 190 in sdpa_solve.cpp
# 31 2.0e-11 8.9e-18 3.1e-11 +8.71e+00 +8.71e+00 3.
# 5e-05 3.5e-05 4.28e+00
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pFEAS
#      iteration = 31
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +8.7140530999194574e+00
#        dualObj = +8.7140530988690656e+00
#     dualityGap = +1.2308932249562904e-10
#    primalError = +0.0000000000000000e+00
#      dualError = +2.5142915546894073e-05
#    convertTime = 0.006346
#      solveTime = 0.317446
# retrievingTime = 0.004170
#      totalTime = 0.333148
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:56 PM: Optimal value: 8.714e+00
# (CVXPY) May 19 02:35:56 PM: Compilation took 5.217e-02 seconds
# (CVXPY) May 19 02:35:56 PM: Solver (including time spent in interface) took 4.051e-01 seconds
# Violation: -0.0
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:56 PM: Your problem has 11 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:56 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:56 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:56 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:57 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:57 PM: Finished problem compilation (took 7.172e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pFEAS
#    Iteration = 31
#           mu = +2.0189756930442268e-11
# relative gap = +1.2053997853576230e-10
#         gap  = +1.0503917735604773e-09
#      digits  = +9.9188688902017788e+00
# objValPrimal = +8.7140530999194574e+00
# objValDual   = +8.7140530988690656e+00
# p.feas.error = +8.8817841970012523e-16
# d.feas.error = +2.5138437194982544e-05
# total time   = 0.304766
#   main loop time = 0.304762
#       total time = 0.304766
# file  check time = 0.000000
# file change time = 0.000004
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pFEAS
#      iteration = 23
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +3.7410340922076424e+00
#        dualObj = +3.7576876876874219e+00
#     dualityGap = +4.4417157933316484e-03
#    primalError = +4.4311533275998016e-08
#      dualError = +1.1909638662473299e-01
#    convertTime = 0.010680
#      solveTime = 0.256718
# retrievingTime = 0.003959
#      totalTime = 0.275753
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:57 PM: Optimal value: 3.741e+00
# (CVXPY) May 19 02:35:57 PM: Compilation took 7.172e-02 seconds
# (CVXPY) May 19 02:35:57 PM: Solver (including time spent in interface) took 3.399e-01 seconds
# Violation: 4.431743675028497e-08
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:57 PM: Your problem has 11 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:57 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:57 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:57 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:57 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:57 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:57 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:57 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:57 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:57 PM: Finished problem compilation (took 6.744e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pFEAS
#    Iteration = 23
#           mu = +1.2436458097425365e-11
# relative gap = +4.4417157933315304e-03
#         gap  = -1.6653595479779515e-02
#      digits  = +2.3524492335715643e+00
# objValPrimal = +3.7410340922076424e+00
# objValDual   = +3.7576876876874219e+00
# p.feas.error = +4.4317436803664734e-08
# d.feas.error = +1.2467018658173350e-01
# total time   = 0.243868
#   main loop time = 0.243863
#       total time = 0.243868
# file  check time = 0.000000
# file change time = 0.000005
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35:57 2024]
# SDPA start at [Sun May 19 14:35:57 2024]
# NumThreads  is set as 64
# Schur computation : DENSE
# Converted to SDPA internal data / Starting SDPA main loop
#    mu      thetaP  thetaD  objP      objD      alphaP  alphaD  beta
# Start: getCLPresult 0 1.0e+04 1.0e+00 1.0e+00 -0.00e+00 +2.80e-02 9.0e-01 6.6e-01 2.00e-01
#  1 2.5e+03 1.0e-01 3.4e-01 +1.39e+03 +3.48e-02 9.0e-01 7.4e-01 2.00e-01
#  2 7.1e+02 1.0e-02 9.0e-02 +1.84e+03 +4.76e-02 9.0e-01 7.7e-01 2.00e-01
#  3 2.1e+02 1.0e-03 2.1e-02 +2.16e+03 +7.16e-02 9.0e-01 9.1e-01 2.00e-01
#  4 5.0e+01 1.0e-04 1.8e-03 +2.03e+03 +1.29e-01 9.0e-01 1.0e+00 2.00e-01
#  5 1.3e+01 1.0e-05 2.2e-07 +7.29e+02 +2.36e-01 9.0e-01 1.0e+00 2.00e-01
#  6 3.3e+00 1.0e-06 1.7e-07 +1.89e+02 +3.82e-01 9.0e-01 1.0e+00 2.00e-01
#  7 8.5e-01 1.0e-07 1.2e-07 +5.01e+01 +5.11e-01 9.0e-01 1.0e+00 2.00e-01
#  8 2.2e-01 1.0e-08 1.4e-07 +1.37e+01 +6.49e-01 6.8e-01 1.0e+00 2.00e-01
#  9 9.9e-02 3.2e-09 2.4e-07 +6.77e+00 +1.10e+00 9.0e-01 7.4e-01 2.00e-01
# 10 3.3e-02 3.2e-10 1.3e-07 +5.19e+00 +3.22e+00 8.1e-01 1.0e+00 2.00e-01
# 11 9.9e-03 3.2e-10 1.6e-07 +4.37e+00 +3.82e+00 1.1e+00 9.3e-01 2.00e-01
# 12 2.1e-03 3.2e-10 1.7e-07 +4.16e+00 +4.06e+00 9.8e-01 1.0e+00 2.00e-01
# 13 4.3e-04 3.2e-10 2.3e-07 +4.13e+00 +4.12e+00 1.1e+00 1.0e+00 2
# Retrieving result from LMI standard form...
# .00e-01
# 14 8.1e-05 3.2e-10 9.5e-08 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 15 1.3e-05 3.2e-10 1.9e-07 +4.13e+00 +4.14e+00 1.4e+00 1.0e+00 2.00e-01
# 16 2.2e-06 3.2e-10 1.8e-07 +4.13e+00 +4.14e+00 1.4e+00 1.0e+00 2.00e-01
# 17 3.6e-07 3.2e-10 2.0e-07 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 18 6.8e-08 3.2e-10 4.5e-08 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 19 1.2e-08 3.2e-10 1.6e-07 +4.13e+00 +4.14e+00 1.1e+00 1.0e+00 2.00e-01
# 20 2.1e-09 3.2e-10 2.3e-07 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 21 3.6e-10 3.2e-10 1.6e-07 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 22 6.5e-11 3.2e-10 7.7e-08 +4.13e+00 +4.14e+00 1.2e+00 1.0e+00 2.00e-01
# 23 1.1e-11 3.2e-10 1.5e-07 +4.13e+00 +4.14e+00 9.9e-07 9.9e-07 2.00e-01
# Step length is too small.  :: line 198 in sdpa_dataset.cpp
# cannot move: step length is too short :: line 190 in sdpa_solve.cpp
# 23 1.1e-11 3.2e-10 1.5e-07 +4.13e+00 +4.14e+00 9.9e-07 9.9e-07 2.00e-01
# Making result infomation...
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pFEAS
#      iteration = 23
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +4.1267036344741070e+00
#        dualObj = +4.1399828342871157e+00
#     dualityGap = +3.2127019364263905e-03
#    primalError = +3.2069431554759831e-08
#      dualError = +1.1649352137465030e-01
#    convertTime = 0.011368
#      solveTime = 0.242079
# retrievingTime = 0.003767
#      totalTime = 0.260948
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:57 PM: Optimal value: 4.127e+00
# (CVXPY) May 19 02:35:57 PM: Compilation took 6.744e-02 seconds
# (CVXPY) May 19 02:35:57 PM: Solver (including time spent in interface) took 3.005e-01 seconds
# Violation: 3.207464398931206e-08

# %% [markdown]
# ### Extracting the weights

# %%
# # Plot the weights
# plt.figure()
# plt.title(f"Eigenvalue lower bound: {lambda_tol:0.3e}")
# plt.plot(wopt, label="weights")
# plt.plot(dual, label="dual weights")
# plt.yscale("log")
# plt.xticks(range(nconfigs), config_ids, rotation=90)
# plt.legend()
# plt.show()

# %%
# Get the optimal buses
idx_wopt = np.where(wopt > 1e-12)[0]  # Index to the optimal buses
print("Optimal buses:")
_ = [print(f'{config_ids[ii]} \t {wopt[ii]}') for ii in idx_wopt]
# Out:
# Optimal buses:
# bus3 	 1.1704499821279137e-07
# bus5 	 0.0001359570325405998
# bus7 	 7.133314592954387e-07
# bus10 	 5.093727603667292e-05
# bus13 	 6.152558307178295e-06

# %%
weighted_fims_configs = fim_configs_tensor * wopt.reshape((-1, 1, 1))
I = np.sum(weighted_fims_configs[idx_wopt], axis=0)
print("Eigenvalues:")
print(np.linalg.eigvalsh(I))

# plt.figure()
# cbound = np.max([-np.min(I), np.max(I)])
# plt.imshow(I, vmin=-cbound, vmax=cbound, cmap="bwr")
# plt.colorbar()
# plt.show()
# Out:
# Eigenvalues:
# [9.96792536e-06 1.09752483e-05 1.30895101e-05 1.56022912e-05
#  2.03738738e-05 2.69372551e-05 3.31680433e-05 3.67210258e-05
#  5.53118656e-05 5.88633147e-05 8.86783936e-05 1.02235756e-04
#  1.41601919e-03 1.58282367e-03 2.08101572e-03 2.32746810e-03
#  3.05826228e-03 3.45923358e-03 3.89503882e-03 4.31008577e-03
#  1.32876149e-02 1.51070480e-02 3.34136647e-02 3.75562093e-02
#  1.15147251e-01 1.29582160e-01 4.18352252e-01 4.38506643e-01]

# %% [markdown]
# # Remove 1 step further

# %%
# Configurations
configs_remove = np.array(configs)[idx_wopt]
configs = list(set(configs) - set(configs_remove))
nconfigs = len(configs)
config_ids = np.array([f"bus{ii}" for ii in configs])
config_ids
# Out:
# array(['bus1', 'bus4', 'bus8', 'bus11', 'bus12', 'bus14'], dtype='<U5')

# %%
# Load configuration FIMs
fim_configs_tensor = np.empty((nconfigs, nparams, nparams))
for ii, bus in enumerate(configs):
    J = np.load(FIM_DIR / f"jacobian_bus{bus}.npy")
    I = J.T @ J
    fim_configs_tensor[ii] = I

# %%
# Convex optimization
# Settings
wopt = np.ones(nconfigs)
for ii in range(4):
    cvxopt = ConvexOpt(fim_configs_tensor, np.array(config_ids), tol_mat, wopt + 1e-15)

    try:
        # Solve
        cvxopt.solve(solver=solver)
    except Exception:
        break

    wopt = cvxopt.result["wm"]
    dual = cvxopt.result["dual_wm"]
    print("Violation:", cvxopt.constraints[1].violation())
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:57 PM: Your problem has 6 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:57 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:57 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:57 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:57 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:57 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:57 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:57 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:57 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:57 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:58 PM: Finished problem compilation (took 4.463e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pFEAS
#    Iteration = 23
#           mu = +1.0797872249662989e-11
# relative gap = +3.2127019364261763e-03
#         gap  = -1.3279199813008624e-02
#      digits  = +2.4931295649464671e+00
# objValPrimal = +4.1267036344741070e+00
# objValDual   = +4.1399828342871157e+00
# p.feas.error = +3.2074644107371597e-08
# d.feas.error = +1.2540679274853134e-01
# total time   = 0.234079
#   main loop time = 0.234074
#       total time = 0.234079
# file  check time = 0.000000
# file change time = 0.000005
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35:57 2024]
# SDPA start at [Sun May 19 14:35:58 2024]
# NumThreads  is set as 64
# Schur computation : DENSE
# Converted to SDPA internal data / Starting SDPA main loop
#    mu      thetaP  thetaD  objP      objD      alphaP  alphaD  beta
#  0 1.0e+04 1.0e+00 1.0e+00 -0.00e+00 +2.80e-02 7.7e-01 7.1e-01 2.00e-01
#  1 3.3e+03 2.3e-01 2.9e-01 +6.39e+02 +2.81e-02 9.0e-01 5.5e-01 2.00e-01
#  2 1.4e+03 2.3e-02 1.3e-01 +9.87e+02 +2.61e-02 9.4e-01 7.9e-01 2.00e-01
#  3 3.8e+02 1.4e-03 2.7e-02 +1.16e+03 +2.16e-02 1.0e+00 8.1e-01 2.00e-01
#  4 1.1e+02 2.3e-15 5.2e-03 +1.09e+03 +1.30e-02 1.6e+00 8.7e-01 2.00e-01
#  5 1.9e+01 4.5e-15 7.0e-04 +1.16e+02 +1.99e-03 1.4e+00 9.0e-01 2.00e-01
#  6 2.9e+00 9.1e-15 7.3e-05 +2.09e+01 +2.03e-04 1.1e+00 9.0e-01 2.00e-01
#  7 5.5e-01 4.5e-15 7.2e-06 +1.10e+01 +2.91e-05 1.2e+00 9.8e-01 2.00e-01
#  8 1.1e-01 4.5e-15 1.5e-07 +4.95e+00 +1.17e-05 1.1e+00 1.0e+00 2.00e-01
#  9 1.6e-02 2.3e-15 1.2e-20 +7.53e-01 +1.08e-05 9.8e-01 9.8e-01 1.00e-01
# 10 2.0e-03 2.1e-15 2.2e-20 +9.18e-02 +1.07e-05 9.9e-01 9.9e-01 1.00e-01
# 11 2.1e-04 2.0e-15 1.2e-20 +9.69e-03 +1.07e-05 9.8e-01 8.6e+01 1.00e-01
# 12 2.4e-05 2.0e-15 3.1e-18 +1.11e-03 +2.77e-05 8.8e-01 9.3e+00 1.00e-01
# 13 4.0e-06 2.0e-15 2.6e-17 +2.54e-04 +7.03e-05 8.4e-01 1.2e+00 1Start: getCLPresult
# Retrieving result from LMI standard form...
# Making result infomation...
# .00e-01
# 14 6.4e-07 2.0e-15 4.7e-18 +1.56e-04 +1.27e-04 8.4e-01 9.0e-01 1.00e-01
# 15 1.4e-07 2.0e-15 4.0e-19 +1.43e-04 +1.36e-04 8.5e-01 7.9e-01 1.00e-01
# 16 3.7e-08 2.0e-15 4.6e-18 +1.41e-04 +1.39e-04 8.5e-01 8.1e-01 1.00e-01
# Strange behavior : primal < dual :: line 158 in sdpa_solve.cpp
# 17 9.6e-09 2.0e-15 2.1e-17 +1.40e-04 +1.40e-04 9.0e-01 9.0e-01 1.00e-01
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pdFEAS
#      iteration = 17
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +1.4036304421456242e-04
#        dualObj = +1.3991936530358492e-04
#     dualityGap = +4.4367891097752137e-07
#    primalError = +0.0000000000000000e+00
#      dualError = +1.8236079313282971e-11
#    convertTime = 0.008353
#      solveTime = 0.107715
# retrievingTime = 0.001917
#      totalTime = 0.121354
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:58 PM: Optimal value: 1.403e-04
# (CVXPY) May 19 02:35:58 PM: Compilation took 4.463e-02 seconds
# (CVXPY) May 19 02:35:58 PM: Solver (including time spent in interface) took 1.491e-01 seconds
# Violation: -0.0
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:58 PM: Your problem has 6 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:58 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:58 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:58 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:58 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:58 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:58 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:58 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:58 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:58 PM: Finished problem compilation (took 5.023e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pdFEAS
#    Iteration = 17
#           mu = +9.6451827045624867e-09
# relative gap = +4.4367891097749426e-07
#         gap  = +4.4367891097749426e-07
#      digits  = +2.4994970604482871e+00
# objValPrimal = +1.4036304421456242e-04
# objValDual   = +1.3991936530358492e-04
# p.feas.error = +2.0144996781823465e-13
# d.feas.error = +1.8166400241742542e-11
# total time   = 0.101198
#   main loop time = 0.101194
#       total time = 0.101198
# file  check time = 0.000000
# file change time = 0.000004
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +3.9179703072192940e+00
#        dualObj = +3.9179703042832328e+00
#     dualityGap = +7.4938355196899999e-10
#    primalError = +0.0000000000000000e+00
#      dualError = +8.2305632531642914e-08
#    convertTime = 0.005342
#      solveTime = 0.145233
# retrievingTime = 0.004081
#      totalTime = 0.156681
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:58 PM: Optimal value: 3.918e+00
# (CVXPY) May 19 02:35:58 PM: Compilation took 5.023e-02 seconds
# (CVXPY) May 19 02:35:58 PM: Solver (including time spent in interface) took 1.879e-01 seconds
# Violation: -0.0
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:58 PM: Your problem has 6 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:58 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:58 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:58 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:58 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:58 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:58 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:58 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:58 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:58 PM: Finished problem compilation (took 4.814e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pdFEAS
#    Iteration = 21
#           mu = +6.3745911857579937e-11
# relative gap = +7.4938321192874291e-10
#         gap  = +2.9360611719653207e-09
#      digits  = +9.1252960404234003e+00
# objValPrimal = +3.9179703072192940e+00
# objValDual   = +3.9179703042832328e+00
# p.feas.error = +2.2204460492503131e-15
# d.feas.error = +8.3079212434089642e-08
# total time   = 0.136084
#   main loop time = 0.136081
#       total time = 0.136084
# file  check time = 0.000000
# file change time = 0.000003
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35:58 2024]
# SDPA start at [Sun May 19 14:35:58 2024]
# NumThreads  is set as 64
# Schur computation : DENSE
# Converted to SDPA internal data / Starting SDPA main loop
#    mu      thetaP  thetaD  objP      objD      alphaP  alphaD  beta
#  0 1.0e+04 1.0e+00 1.0e+00 -0.00e+00 +2.80e-02 9.0e-01 6.4e-01 2.00e-01
#  1 2.3e+03 1.0e-01 3.6e-01 +7.68e+02 +3.44e-02 9.0e-01 7.8e-01 2.00e-01
#  2 5.3e+02 1.0e-02 8.0e-02 +1.01e+03 +4.72e-02 9.0e-01 7.7e-01 2.00e-01
#  3 1.5e+02 1.0e-03 1.8e-02 +1.17e+03 +6.89e-02 9.0e-01 8.9e-01 2.00e-01
#  4 3.7e+01 1.0e-04 1.9e-03 +1.07e+03 +1.16e-01 9.0e-01 1.0e+00 2.00e-01
#  5 9.7e+00 1.0e-05 1.0e-07 +4.17e+02 +1.84e-01 9.0e-01 1.0e+00 2.00e-01
#  6 2.6e+00 1.0e-06 8.6e-08 +1.12e+02 +2.68e-01 9.0e-01 1.0e+00 2.00e-01
#  7 6.8e-01 1.0e-07 6.4e-08 +3.09e+01 +3.55e-01 9.0e-01 1.0e+00 2.00e-01
#  8 1.9e-01 1.0e-08 4.6e-08 +8.82e+00 +4.68e-01 6.7e-01 1.0e+00 2.00e-01
#  9 8.2e-02 3.3e-09 9.9e-08 +4.59e+00 +9.42e-01 9.0e-01 7.7e-01 2.00e-01
# 10 2.8e-02 3.3e-10 5.2e-08 +3.85e+00 +2.59e+00 9.3e-01 9.6e-01 2.00e-01
# 11 6.8e-03 3.3e-10 3.9e-08 +3.49e+00 +3.20e+00 9.6e-01 9.6e-01 2.00e-01
# 12 1.6e-03 3.3e-10 2.3e-09 +3.43e+00 +3.37e+00 1.0e+00 1.0e+00 2.00e-01
# 13 3.1e-04 3.3e-10 1.3e-07 +3.42e+00 +3.41e+00 1.1e+00 1.0e+00 2Start: getCLPresult
# Retrieving result from LMI standard form...
# Making result infomation...
# .00e-01
# 14 5.7e-05 3.3e-10 3.9e-08 +3.41e+00 +3.42e+00 1.4e+00 1.0e+00 2.00e-01
# 15 1.0e-05 3.3e-10 4.6e-08 +3.41e+00 +3.42e+00 1.8e+00 1.0e+00 2.00e-01
# 16 1.7e-06 3.3e-10 2.9e-08 +3.41e+00 +3.42e+00 1.3e+00 1.0e+00 2.00e-01
# 17 3.4e-07 3.3e-10 1.9e-08 +3.41e+00 +3.42e+00 1.1e+00 1.0e+00 2.00e-01
# 18 6.3e-08 3.3e-10 4.3e-08 +3.41e+00 +3.42e+00 1.1e+00 1.0e+00 2.00e-01
# 19 1.2e-08 3.3e-10 2.5e-08 +3.41e+00 +3.42e+00 1.2e+00 1.0e+00 2.00e-01
# 20 2.2e-09 3.3e-10 5.0e-08 +3.41e+00 +3.42e+00 1.2e+00 1.0e+00 2.00e-01
# 21 4.1e-10 3.3e-10 2.1e-08 +3.41e+00 +3.42e+00 1.2e+00 1.0e+00 2.00e-01
# 22 7.4e-11 3.3e-10 4.0e-08 +3.41e+00 +3.42e+00 1.2e+00 1.0e+00 2.00e-01
# 23 1.4e-11 3.3e-10 5.4e-10 +3.41e+00 +3.42e+00 1.2e+00 1.0e+00 2.00e-01
# 24 2.6e-12 3.3e-10 1.1e-07 +3.41e+00 +3.42e+00 1.0e-06 1.0e-06 2.00e-01
# Step length is too small.  :: line 198 in sdpa_dataset.cpp
# cannot move: step length is too short :: line 190 in sdpa_solve.cpp
# 24 2.6e-12 3.3e-10 1.1e-07 +3.41e+00 +3.42e+00 1.0e-06 1.0e-06 2.00e-01
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pFEAS
#      iteration = 24
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +3.4129328911401418e+00
#        dualObj = +3.4240783600380595e+00
#     dualityGap = +3.2603336424222272e-03
#    primalError = +3.2548510581209555e-08
#      dualError = +8.9704640580748674e-02
#    convertTime = 0.007318
#      solveTime = 0.161590
# retrievingTime = 0.001630
#      totalTime = 0.174156
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:58 PM: Optimal value: 3.413e+00
# (CVXPY) May 19 02:35:58 PM: Compilation took 4.814e-02 seconds
# (CVXPY) May 19 02:35:58 PM: Solver (including time spent in interface) took 2.126e-01 seconds
# Violation: 3.254970403765643e-08
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) May 19 02:35:58 PM: Your problem has 6 variables, 2 constraints, and 0 parameters.
# (CVXPY) May 19 02:35:58 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) May 19 02:35:58 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) May 19 02:35:58 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Compiling problem (target solver=SDPA).
# (CVXPY) May 19 02:35:58 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SDPA
# (CVXPY) May 19 02:35:58 PM: Applying reduction Dcp2Cone
# (CVXPY) May 19 02:35:58 PM: Applying reduction CvxAttr2Constr
# (CVXPY) May 19 02:35:58 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) May 19 02:35:58 PM: Applying reduction SDPA
# (CVXPY) May 19 02:35:58 PM: Finished problem compilation (took 4.846e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:58 PM: Invoking solver SDPA  to obtain a solution.
# ---------- SDPAP Start ----------
# Converting CLP format to LMI standard form...
#
# phase.value  = pFEAS
#    Iteration = 24
#           mu = +2.5674612198166447e-12
# relative gap = +3.2603336424222272e-03
#         gap  = -1.1145468897917787e-02
#      digits  = +2.4867379546410757e+00
# objValPrimal = +3.4129328911401418e+00
# objValDual   = +3.4240783600380595e+00
# p.feas.error = +3.2549704029327664e-08
# d.feas.error = +9.3836876776111286e-02
# total time   = 0.156123
#   main loop time = 0.156120
#       total time = 0.156123
# file  check time = 0.000000
# file change time = 0.000003
# file   read time = 0.000000
# Converting optimal solution to CLP format
# SDPA end at [Sun May 19 14:35:58 2024]
# SDPA start at [Sun May 19 14:35:58 2024]
# NumThreads  is set as 64
# Schur computation : DENSE
# Converted to SDPA internal data / Starting SDPA main loop
#    mu      thetaP  thetaD  objP      objD      alphaP  alphaD  beta
# Start: getCLPresult
# Retrieving result from LMI standard form...
# Making result infomation...
#  0 1.0e+04 1.0e+00 1.0e+00 -0.00e+00 +2.80e-02 9.0e-01 6.3e-01 2.00e-01
#  1 2.3e+03 1.0e-01 3.7e-01 +7.77e+02 +3.39e-02 9.0e-01 7.9e-01 2.00e-01
#  2 5.3e+02 1.0e-02 7.8e-02 +1.02e+03 +4.71e-02 9.0e-01 7.7e-01 2.00e-01
#  3 1.5e+02 1.0e-03 1.8e-02 +1.18e+03 +6.75e-02 9.0e-01 9.3e-01 2.00e-01
#  4 3.3e+01 1.0e-04 1.2e-03 +1.07e+03 +1.22e-01 9.0e-01 1.0e+00 2.00e-01
#  5 8.2e+00 1.0e-05 1.2e-08 +3.46e+02 +2.17e-01 9.0e-01 1.0e+00 2.00e-01
#  6 2.1e+00 1.0e-06 2.0e-07 +9.04e+01 +3.77e-01 9.0e-01 1.0e+00 2.00e-01
#  7 5.5e-01 1.0e-07 1.4e-07 +2.47e+01 +5.80e-01 8.9e-01 1.0e+00 2.00e-01
#  8 1.5e-01 1.1e-08 8.6e-08 +7.64e+00 +8.72e-01 5.4e-01 1.0e+00 2.00e-01
#  9 7.4e-02 5.2e-09 4.0e-08 +5.37e+00 +2.23e+00 9.0e-01 5.6e-01 2.00e-01
# 10 3.6e-02 5.2e-10 2.9e-08 +5.15e+00 +3.51e+00 9.1e-01 1.0e+00 2.00e-01
# 11 8.3e-03 5.2e-10 5.3e-08 +4.67e+00 +4.33e+00 9.5e-01 9.9e-01 2.00e-01
# 12 1.8e-03 5.2e-10 6.2e-09 +4.59e+00 +4.53e+00 9.8e-01 1.0e+00 2.00e-01
# 13 3.6e-04 5.2e-10 1.9e-07 +4.57e+00 +4.58e+00 1.1e+00 1.0e+00 2.00e-01
# 14 6.8e-05 5.2e-10 1.2e-07 +4.57e+00 +4.59e+00 1.3e+00 1.0e+00 2.00e-01
# 15 1.2e-05 5.2e-10 2.5e-08 +4.57e+00 +4.59e+00 1.6e+00 1.0e+00 2.00e-01
# 16 2.2e-06 5.2e-10 1.2e-07 +4.57e+00 +4.59e+00 1.5e+00 1.0e+00 2.00e-01
# 17 3.8e-07 5.2e-10 8.1e-08 +4.57e+00 +4.59e+00 1.1e+00 1.0e+00 2.00e-01
# 18 7.5e-08 5.2e-10 5.0e-08 +4.57e+00 +4.59e+00 1.1e+00 1.0e+00 2.00e-01
# 19 1.4e-08 5.2e-10 4.7e-08 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 20 2.6e-09 5.2e-10 1.1e-08 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 21 4.7e-10 5.2e-10 8.6e-08 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 22 9.0e-11 5.2e-10 7.2e-08 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 23 1.6e-11 5.2e-10 4.1e-10 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 24 3.1e-12 5.2e-10 7.4e-08 +4.57e+00 +4.59e+00 1.2e+00 1.0e+00 2.00e-01
# 25 5.6e-13 5.2e-10 7.4e-08 +4.57e+00 +4.59e+00 1.0e-06 1.0e-06 2.00e-01
# Step length is too small.  :: line 198 in sdpa_dataset.cpp
# cannot move: step length is too short :: line 190 in sdpa_solve.cpp
# 25 5.6e-13 5.2e-10 7.4e-08 +4.57e+00 +4.59e+00 1.0e-06 1.0e-06 2.00e-01
# ========================================
#  SDPAP: Result
# ========================================
#     SDPA.phase = pFEAS
#      iteration = 25
#     convMethod = LMI
#      frvMethod = split
#   domainMethod = none
#    rangeMethod = none
#      primalObj = +4.5706536581657371e+00
#        dualObj = +4.5944960636623406e+00
#     dualityGap = +5.2028403725513971e-03
#    primalError = +5.1892472319181593e-08
#      dualError = +8.7781201958023303e-02
#    convertTime = 0.006938
#      solveTime = 0.171658
# retrievingTime = 0.002156
#      totalTime = 0.183631
# ---------- SDPAP End ----------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) May 19 02:35:59 PM: Problem status: optimal_inaccurate
# (CVXPY) May 19 02:35:59 PM: Optimal value: 4.571e+00
# (CVXPY) May 19 02:35:59 PM: Compilation took 4.846e-02 seconds
# (CVXPY) May 19 02:35:59 PM: Solver (including time spent in interface) took 2.212e-01 seconds
# Violation: 5.189272951960271e-08

# %%
# Get the optimal buses
idx_wopt = np.where(wopt > 1e-12)[0]  # Index to the optimal buses
print("Optimal buses:")
_ = [print(f'{config_ids[ii]} \t {wopt[ii]}') for ii in idx_wopt]
# Out:
# Optimal buses:
# bus1 	 2.1157764378165252e-08
# bus4 	 0.00016125191334759596
# bus11 	 4.2448283246930655e-05
# bus12 	 2.8722881156670066e-07
# bus14 	 6.066826519146895e-06

# %%
weighted_fims_configs = fim_configs_tensor * wopt.reshape((-1, 1, 1))
I = np.sum(weighted_fims_configs[idx_wopt], axis=0)
print("Eigenvalues:")
print(np.linalg.eigvalsh(I))
# Out:
# Eigenvalues:
# [9.94810727e-06 1.05422906e-05 1.21439424e-05 1.44620186e-05
#  1.78800478e-05 2.07916491e-05 2.82284345e-05 3.06492058e-05
#  4.22358167e-05 4.62257390e-05 1.26265960e-04 1.48649611e-04
#  4.40700602e-04 5.05351733e-04 1.03289689e-03 1.16253647e-03
#  2.18968739e-03 2.43997387e-03 4.91773027e-03 5.19688193e-03
#  9.27795953e-03 1.04591213e-02 1.81712216e-02 1.93762049e-02
#  1.19882250e-01 1.34826171e-01 5.42055086e-01 5.75489258e-01]
